# %%
from pathlib import Path
import json

input_path = Path("./output/flattend_koksl2022_ann.json")

with open(input_path, "r", encoding="utf-8") as file:
    input_records = json.loads(file.read())

# %%
import re

def get_left_wds(target_wd: str, ksl_snt: str):
    ksl_wds = ksl_snt.split("/")
    ksl_wds_norm = [re.sub(r"\[.+?\]$", "", wd) for wd in ksl_wds]

    target_idxs = (i for i, wd in enumerate(ksl_wds_norm) if wd == target_wd)

    def get_left_wd(idx: int):
        if idx < 1:
            return "Init"
        else:
            return ksl_wds[idx - 1]
    return [get_left_wd(i) for i in target_idxs]

left_wds = {
    "아니다": [],
    "없다": [],
    "않다": [],
    "안하다": [],
}

for record in input_records:
    ksl_snt = record["ksl_simple"]
    left_wds["아니다"] += get_left_wds("아니다", ksl_snt)
    left_wds["없다"] += get_left_wds("없다", ksl_snt)
    left_wds["않다"] += get_left_wds("않다", ksl_snt)
    left_wds["안하다"] += get_left_wds("안하다", ksl_snt)

left_wds["아니다"]
# Out:
# ['냉동',
#  'Init',
#  '화면',
#  '문제',
#  'Init',
#  'Init',
#  'Init',
#  '담당',
#  'Init',
#  '사다',
#  '어렵다',
#  '고장(결함)',
#  '고장(결함)',
#  'Init',
#  '오르다',
#  'Init',
#  '에어컨',
#  '세우다',
#  '들어(상태)오다',
#  '들어(상태)오다',
#  'Init',
#  'Init',
#  '전화번호',
#  '#완산구',
#  '달라',
#  '오다',
#  '불량',
#  '구입',
#  '통세탁기',
#  'Init',
#  'Init',
#  'Init',
#  'Init',
#  'Init',
#  'Init',
#  '사다',
#  'Init',
#  'Init',
#  'Init',
#  '다르다',
#  '문제',
#  '들리다',
#  '켜지다',
#  'Init',
#  '통돌이',
#  '담당',
#  '100 200만원',
#  '이사(행동)',
#  '사용',
#  '무료(공짜)',
#  '늦다',
#  'Init',
#  '작다',
#  '말(대화)주다',
#  '잘못',
#  'Init',
#  '원하다',
#  '동의',
#  '꺾이다',
#  'Init',
#  '사용',
#  '나오다',
#  '맞다(옳다)',
#  '2',
#  '어렵다',
#  'Init',
#  'Init',
#  '멈추다',
#  'Init',
#  'Init',
#  'Init',
#  'Init',
#  '오래',
#  '들어가다',
#  'Init',
#  '곳',
#  'Init',
#  'Init',
#  '원하다',
#  '원하다',
#  'Init',
#  '앞 열다',
#  '모두',
#  '다',
#  '멀다',
#  'Init',
#  '지금',
#  'Init',
#  '담당',
#  'Init',
#  'Init',
#  '같다(추측)',
#  '버튼누르다',
#  'Init',
#  '내거',
#  '묻다',
#  '그것',
#  'Init',
#  '전(시간)',
#  '대로(어미)',
#  '현금',
#  'Init',
#  'Init',
#  'Init',
#  'Init',
#  'Init',
#  '새(신)거',
#  'Init',
#  '사용',
#  'Init',
#  '들어(상태)가다',
#  '담당',
#  '충분',
#  '결제',
#  '물건',
#  'Init',
#  'Init',
#  'Init',
#  '부서',
#  '잘못',
#  'Init',
#  'Init',
#  'Init',
#  '블랙',
#  'Init',
#  'Init',
#  'Init',
#  '맞다(옳다)',
#  'Init',
#  '끝',
#  'Init',
#  '보내다',
#  'Init',
#  'Init',
#  '맘에들다(상태)',
#  '계산',
#  'Init',
#  '문제',
#  'Init',
#  'Init',
#  '물건',
#  'Init',
#  '주문',
#  '방법',
#  'Init',
#  '기준',
#  '거짓',
#  '원하다',
#  '바보',
#  'Init',
#  'Init',
#  '교환',
#  '시계',
#  '본인',
#  'Init',
#  '필요',
#  '나',
#  '그대로',
#  'Init',
#  'Init',
#  '#세트',
#  '오다',
#  'Init',
#  'Init',
#  '나다',
#  'Init',
#  '물건',
#  'Init',
#  '오다',
#  '가져가다',
#  '가져가다',
#  '그것',
#  '환불',
#  '지시[그런건]',
#  '결제',
#  '색깔',
#  'Init',
#  '가지고 있다',
#  'Init',
#  'Init',
#  'Init',
#  '중요하다',
#  '원하다',
#  'Init',
#  '이것',
#  '배송',
#  'Init',
#  '묻다(질문)',
#  'Init',
#  '쓰다(작성)',
#  '신청',
#  'Init',
#  '구입',
#  'Init',
#  '정도',
#  'Init',
#  'Init',
#  'Init',
#  '물건',
#  '교환',
#  'Init',
#  '좋다',
#  'Init',
#  '결정',
#  '반품',
#  '카드',
#  '나오다',
#  '입금',
#  'Init',
#  '오다',
#  'Init',
#  'Init',
#  '어렵다',
#  '길다',
#  '길다',
#  '포함',
#  '취소',
#  '담당',
#  '팔다',
#  '주다',
#  'Init',
#  'Init',
#  'Init',
#  'Init',
#  'Init',
#  'Init',
#  '사다',
#  '질문',
#  'Init',
#  '급(급함)하다',
#  '배송',
#  '다르다',
#  'Init',
#  '불량',
#  '맞다(옳다)',
#  'Init',
#  'Init',
#  '환불',
#  'Init',
#  'Init',
#  'Init',
#  '정확',
#  'Init',
#  'Init',
#  '활용',
#  'Init',
#  'Init',
#  'Init',
#  'Init',
#  'Init',
#  '시작',
#  'Init',
#  '원하다',
#  'Init',
#  '취소',
#  'Init',
#  '택배 보내다',
#  '번호',
#  'Init',
#  '담당',
#  '원하다',
#  'Init',
#  '다르다',
#  '제주도',
#  'Init',
#  'Init',
#  '카메라',
#  'Init',
#  '다르다',
#  'Init',
#  '다르다',
#  '회원',
#  '회원',
#  'Init',
#  '사항',
#  '참여하다',
#  '포함',
#  '지시[여기]',
#  '포함',
#  '어울리다',
#  '카드',
#  '똑같다',
#  '똑같다',
#  'Init',
#  '점수판',
#  '타월',
#  '7만원',
#  'Init',
#  '대로(어미)',
#  '보호자',
#  '직접',
#  '말(대화)',
#  '이벤트',
#  'Init',
#  '1',
#  '주다',
#  'Init',
#  'Init',
#  '할인',
#  'Init',
#  '맞다(옳다)',
#  '물건',
#  '특별',
#  '맞다(옳다)',
#  'Init',
#  'Init',
#  '오래',
#  '불가능',
#  'Init',
#  'Init',
#  'Init',
#  '다르다',
#  '교환',
#  '교환',
#  '역할',
#  'Init',
#  'Init',
#  'Init',
#  'Init',
#  '쿠폰',
#  '사용',
#  '쉽다',
#  'Init',
#  '불량',
#  '다르다',
#  'Init',
#  '할인',
#  '불만',
#  '불가',
#  'Init',
#  '끝',
#  '손해',
#  '있다',
#  'Init',
#  '주문하다',
#  '사용',
#  'Init',
#  '할인',
#  '할인',
#  'Init',
#  'Init',
#  '심하다',
#  'Init',
#  '가능',
#  '길다',
#  '주다',
#  'Init',
#  '뿐',
#  '나오다',
#  '사진',
#  '돈',
#  '다르다',
#  '맞다(옳다)',
#  '맞다(옳다)',
#  '원하다',
#  'Init',
#  'Init',
#  'Init',
#  'Init',
#  '높다',
#  'Init',
#  'Init',
#  'Init',
#  'Init',
#  'Init',
#  'Init',
#  'Init',
#  '바로',
#  'Init',
#  '다름',
#  'Init',
#  'Init',
#  '목적',
#  '바르다(옳다)',
#  '많다',
#  'Init',
#  '잘못',
#  '적다(쓰다)',
#  'Init',
#  '안되다',
#  'Init',
#  'Init',
#  '#VIP',
#  'Init',
#  'Init',
#  'Init',
#  'Init',
#  'Init',
#  '사다',
#  'Init',
#  'Init',
#  'Init',
#  'Init',
#  'Init',
#  '책임',
#  '책임',
#  'Init',
#  '계산',
#  'Init',
#  '사라지다',
#  'Init',
#  'Init',
#  'Init',
#  '취소',
#  'Init',
#  'Init',
#  '드리다',
#  'Init',
#  'Init',
#  'Init',
#  'Init',
#  'Init',
#  'Init',
#  'Init',
#  '있어',
#  '적립',
#  'Init',
#  '길다',
#  'Init',
#  'Init',
#  '적립',
#  '다르다',
#  'Init',
#  '되다',
#  'Init',
#  '얼마',
#  'Init',
#  '주다',
#  '길다',
#  '길다',
#  'Init',
#  '오래',
#  '그런데',
#  '물건',
#  '원하다',
#  '동의',
#  '오래',
#  '회원',
#  '회원',
#  '회원',
#  '회원',
#  '회원',
#  '추천',
#  '점(단위)',
#  '정도',
#  'Init',
#  'Init',
#  '까지',
#  'Init',
#  'Init',
#  'Init',
#  'Init',
#  'Init',
#  'Init',
#  '그',
#  '책',
#  '물건',
#  'Init',
#  '보다(구경)',
#  'Init',
#  '주다',
#  '가입',
#  'Init',
#  '다르다',
#  'Init',
#  '다르다',
#  '길다',
#  '작다',
#  '몇일(날)전(시간)',
#  'Init',
#  'Init',
#  'Init',
#  '쉽다',
#  '주다',
#  'Init',
#  'Init',
#  '다르다',
#  '자르다',
#  '자르다',
#  '다르다',
#  '말(대화)하다',
#  '여기',
#  'Init',
#  'Init',
#  '다르다',
#  'Init',
#  'Init',
#  'Init',
#  '가능',
#  '사라지다',
#  'Init',
#  'Init',
#  '물건',
#  '물건',
#  '스타일',
#  'Init',
#  'Init',
#  '복잡',
#  '어렵다',
#  'Init',
#  '다르다',
#  'Init',
#  'Init',
#  'Init',
#  'Init',
#  'Init',
#  'Init',
#  '정하다',
#  'Init',
#  'Init',
#  '그것',
#  '남다',
#  '적당히',
#  'Init',
#  'Init',
#  'Init',
#  'Init',
#  'Init',
#  'Init',
#  '맞다(옳다)',
#  'Init',
#  'Init',
#  '다르다',
#  'Init',
#  'Init',
#  'Init',
#  '있다',
#  'Init',
#  'Init',
#  'Init',
#  'Init',
#  'Init',
#  '영광',
#  '돌려주다',
#  '결정(행동)',
#  '계정',
#  'Init',
#  '물건',
#  'Init',
#  '[나에게]신청',
#  '사업자등록증',
#  '뿐',
#  'Init',
#  '못(부정)하다',
#  'Init',
#  'Init',
#  '팔다',
#  '물건',
#  '맞다(옳다)',
#  'Init',
#  '사라지다',
#  'Init',
#  '주다',
#  '오다',
#  'Init',
#  'Init',
#  '질문',
#  '쓰다(사용)',
#  'Init',
#  'Init',
#  '주다',
#  '적용',
#  '똑같다',
#  '문제',
#  '정확',
#  'Init',
#  '리모컨',
#  '회사',
#  '회원',
#  '회원',
#  'Init',
#  '도와주다',
#  '모으다',
#  '해(하다)보다',
#  '되다',
#  '구글스토어',
#  '마이페이지',
#  'Init',
#  '바뀌다',
#  'Init',
#  'Init',
#  'Init',
#  '때(시간)',
#  'Init',
#  '만(어미)',
#  'Init',
#  'Init',
#  'Init',
#  '찾다',
#  '접속',
#  '접속',
#  '상품(제품)',
#  '꼭',
#  '다르다',
#  'Init',
#  'Init',
#  '다르다',
#  'Init',
#  'Init',
#  '결정(행동)',
#  '오래',
#  'Init',
#  'Init',
#  '방법',
#  '가다',
#  'Init',
#  '다르다',
#  'Init',
#  '다르다',
#  'Init',
#  '쉽다',
#  '꼭',
#  'Init',
#  '이름',
#  '다르다',
#  '거절',
#  'Init',
#  '인출',
#  '어렵다',
#  'Init',
#  '출국',
#  '다르다',
#  'Init',
#  '다르다',
#  '누르다',
#  'Init',
#  '회원',
#  '인정(긍정)',
#  'Init',
#  '있다',
#  'Init',
#  '오래',
#  'Init',
#  '맞다(옳다)',
#  '다르다',
#  'Init',
#  '회원',
#  '회원',
#  '회원',
#  '어렵다',
#  'Init',
#  '곳',
#  'Init',
#  'Init',
#  '가능',
#  '같다(추측)',
#  'Init',
#  'Init',
#  '팔다',
#  'Init',
#  'Init',
#  'Init',
#  'Init',
#  'Init',
#  'Init',
#  'Init',
#  'Init',
#  'Init',
#  'Init',
#  '회원',
#  'Init',
#  '다르다',
#  '중요',
#  'Init',
#  '사람',
#  'Init',
#  '안돼',
#  '회원',
#  '특별하다',
#  '죄송',
#  '중(가운데)',
#  'Init',
#  '결제',
#  'Init',
#  'Init',
#  'Init',
#  '다르다',
#  '다르다',
#  'Init',
#  '다르다',
#  'Init',
#  'Init',
#  'Init',
#  'Init',
#  '홈페이지',
#  '개인',
#  'Init',
#  'Init',
#  'Init',
#  'Init',
#  '날(시간)',
#  'Init',
#  '보다(구경)',
#  '홈페이지',
#  '뿐',
#  'Init',
#  '다르다',
#  '인터넷',
#  '뿐',
#  'Init',
#  'Init',
#  'Init',
#  'Init',
#  '꼭',
#  '상황',
#  '되다',
#  'Init',
#  'Init',
#  'Init',
#  '뿐',
#  '남다',
#  '있다',
#  '맞다(옳다)',
#  '되다',
#  'Init',
#  '때(시간)',
#  'Init',
#  'Init',
#  '원하다',
#  'Init',
#  '오다',
#  'Init',
#  '포인트',
#  'Init',
#  'Init',
#  'Init',
#  '나오다',
#  'Init',
#  'Init',
#  'Init',
#  '것',
#  'Init',
#  '것',
#  '쓰다(사용)',
#  'Init',
#  'Init',
#  '주문',
#  '가다',
#  '쓰다(작성)',
#  'Init',
#  '잘못',
#  'Init',
#  '되다',
#  '같다',
#  'Init',
#  '정보',
#  'Init',
#  'Init',
#  'Init',
#  '회원',
#  '회원',
#  '그거',
#  '뿐',
#  'Init',
#  '잘',
#  '로그인',
#  '열다',
#  '연결',
#  '회원',
#  '회원',
#  '회원',
#  '출국',
#  '출국',
#  '이름',
#  'Init',
#  '그거',
#  'Init',
#  'Init',
#  '나오다',
#  '되다',
#  'Init',
#  'Init',
#  '다르다',
#  '가입',
#  'Init',
#  'Init',
#  '다르다',
#  'Init',
#  '회원',
#  '회원',
#  '가입하다',
#  '다르다',
#  '어렵다',
#  '다르다',
#  '특별',
#  '사다',
#  '월요일',
#  '오다',
#  'Init',
#  '있다',
#  '오다',
#  '복구',
#  '원하다',
#  '주다',
#  '주다',
#  '청구',
#  '어렵다',
#  '바쁘다',
#  '이름',
#  '이름',
#  'Init',
#  'Init',
#  '센터',
#  '회원',
#  '회원',
#  '회원',
#  'Init',
#  'Init',
#  '사라지다',
#  '오래',
#  '오래',
#  'Init',
#  '중(가운데)',
#  '날(시간)',
#  'Init',
#  '준비',
#  '원활',
#  'Init',
#  '정하다',
#  '다르다',
#  'Init',
#  'Init',
#  'Init',
#  'Init',
#  'Init',
#  'Init',
#  '책',
#  'Init',
#  '다르다',
#  'Init',
#  'Init',
#  '전혀',
#  '바뀌다',
#  'Init',
#  'Init',
#  'Init',
#  'Init',
#  '별거',
#  'Init',
#  '다른거',
#  'Init',
#  '것',
#  '회원',
#  '궁금',
#  '필수',
#  'Init',
#  '노트북',
#  '노트북',
#  '뿐',
#  '적합하다',
#  'Init',
#  'Init',
#  '들어가다',
#  '다르다',
#  '특별하다',
#  'Init',
#  'Init',
#  '어렵다',
#  '문의',
#  'Init',
#  'Init',
#  '다르다',
#  '많다',
#  'Init',
#  'Init',
#  '회원',
#  '다르다',
#  'Init',
#  '경기(지명)도(주소)',
#  'Init',
#  '안녕하세요',
#  'Init',
#  'Init',
#  'Init',
#  'Init',
#  'Init',
#  'Init',
#  'Init',
#  'Init',
#  'Init',
#  '잘못',
#  'Init',
#  'Init',
#  'Init',
#  'Init',
#  '같다',
#  '무엇',
#  '회원',
#  'Init',
#  '회원',
#  '회원',
#  'Init',
#  '오래',
#  '일(업무)',
#  'Init',
#  '다르다',
#  '맞다(옳다)',
#  'Init',
#  'ID',
#  'Init',
#  'Init',
#  'Init',
#  'Init',
#  'Init',
#  'Init',
#  'Init',
#  'Init',
#  'Init',
#  '사람',
#  '문제',
#  '다르다',
#  '오로지',
#  'Init',
#  'Init',
#  'Init',
#  '오랫동안',
#  '책임',
#  'Init',
#  'Init',
#  '사다',
#  'Init',
#  '대로(어미)',
#  'Init',
#  'Init',
#  '내용',
#  'Init',
#  '발송',
#  'Init',
#  'Init',
#  'Init',
#  '자다',
#  '문제',
#  '문제',
#  'Init',
#  'Init',
#  'Init',
#  '때(시간)',
#  'Init',
#  '많다',
#  '부터',
#  '여섯시',
#  'Init',
#  '예약',
#  'Init',
#  'Init',
#  '어머',
#  'Init',
#  '알다',
#  '이곳',
#  'Init',
#  'Init',
#  '모습',
#  'Init',
#  '성인',
#  'Init',
#  '지금',
#  '침대',
#  '뷔페',
#  '새벽',
#  '끝',
#  'Init',
#  'Init',
#  '주다',
#  '가족',
#  '무료(공짜)',
#  'Init',
#  '많다',
#  '많다',
#  'Init',
#  '예약',
#  '기간',
#  'Init',
#  'Init',
#  'Init',
#  '전문(프로)',
#  'Init',
#  'Init',
#  '주차장',
#  'Init',
#  'Init',
#  'Init',
#  '많다',
#  '많다',
#  '많다',
#  '많다',
#  'Init',
#  '#모텔',
#  '크다',
#  '늦다',
#  'Init',
#  '비싸다',
#  'Init',
#  '많다',
#  '오다',
#  '10%',
#  'Init',
#  '걱정',
#  'Init',
#  '최고',
#  '되다',
#  ...]

# %%
left_wd_set = {
    *left_wds["아니다"], 
    *left_wds["없다"], 
    *left_wds["않다"], 
    *left_wds["안하다"],
    }

def get_count_by_neg(wd):
    num_ani = left_wds["아니다"].count(wd)
    num_eps = left_wds["없다"].count(wd)
    num_anh = left_wds["않다"].count(wd)
    num_anha = left_wds["안하다"].count(wd)
    return (
        wd,
        num_ani,
        num_eps,
        num_anh,
        num_anha
    )

left_wd_count = [get_count_by_neg(wd) for wd in left_wd_set if not wd == "Init"]
left_wd_count = sorted(left_wd_count, key=lambda wd: wd[1], reverse=True)
left_wd_count
# Out:
# [('다르다', 169, 47, 0, 0),
#  ('좋다', 164, 7, 23, 0),
#  ('심하다', 97, 21, 5, 0),
#  ('많다', 68, 15, 3, 1),
#  ('먹다', 66, 103, 49, 4),
#  ('주다', 59, 99, 3, 4),
#  ('맞다(옳다)', 58, 5, 0, 0),
#  ('문제', 55, 319, 0, 0),
#  ('뿐', 47, 2, 0, 0),
#  ('나쁘다', 47, 34, 6, 0),
#  ('있다', 46, 217, 0, 0),
#  ('쉽다', 41, 1, 14, 0),
#  ('담당', 41, 1, 0, 0),
#  ('아프다', 40, 170, 7, 0),
#  ('오래', 36, 1, 0, 0),
#  ('회원', 35, 40, 0, 0),
#  ('암', 32, 1, 0, 0),
#  ('원하다', 32, 3, 10, 0),
#  ('정도', 31, 1, 0, 0),
#  ('필요', 30, 106, 0, 1),
#  ('오다', 29, 16, 5, 1),
#  ('곳', 28, 61, 0, 0),
#  ('크다', 23, 22, 1, 1),
#  ('수술', 23, 17, 0, 6),
#  ('사람', 22, 88, 0, 0),
#  ('가능', 21, 4, 0, 0),
#  ('되다', 21, 3, 0, 0),
#  ('특별', 20, 60, 0, 0),
#  ('병(질병)', 20, 10, 0, 0),
#  ('끝', 19, 2, 0, 0),
#  ('어렵다', 18, 28, 4, 0),
#  ('높다', 17, 1, 4, 0),
#  ('여기', 17, 2, 0, 0),
#  ('길다', 17, 1, 1, 0),
#  ('그것', 17, 3, 0, 0),
#  ('가다', 17, 4, 11, 2),
#  ('꼭', 16, 2, 0, 0),
#  ('포함', 16, 24, 0, 0),
#  ('다름', 15, 2, 0, 0),
#  ('일(업무)', 15, 48, 0, 2),
#  ('목적', 15, 6, 0, 0),
#  ('자주(빈번)', 15, 2, 0, 0),
#  ('검사(검진)', 14, 23, 0, 1),
#  ('생기다', 14, 26, 1, 0),
#  ('사라지다', 14, 10, 3, 0),
#  ('멀다', 13, 0, 3, 0),
#  ('나오다', 13, 63, 1, 0),
#  ('비(부정)싸다(가격)', 12, 0, 1, 0),
#  ('만(어미)', 12, 3, 0, 0),
#  ('대상', 12, 0, 0, 0),
#  ('잘못', 11, 2, 0, 0),
#  ('느낌', 11, 35, 0, 0),
#  ('힘들다', 11, 36, 1, 0),
#  ('그런데', 11, 4, 0, 1),
#  ('무료(공짜)', 11, 1, 0, 0),
#  ('물건', 11, 13, 0, 0),
#  ('관련', 10, 16, 0, 0),
#  ('약(물질)', 10, 44, 0, 0),
#  ('보다(구경)', 9, 3, 1, 0),
#  ('지금', 9, 69, 0, 0),
#  ('원인', 9, 0, 0, 0),
#  ('해결', 9, 10, 0, 0),
#  ('사다', 9, 3, 0, 1),
#  ('나', 9, 3, 0, 1),
#  ('사용', 9, 56, 5, 4),
#  ('같다', 9, 1, 0, 0),
#  ('괜찮다', 9, 7, 0, 0),
#  ('불편', 8, 82, 0, 0),
#  ('못하다', 8, 0, 0, 0),
#  ('늦다', 8, 3, 2, 0),
#  ('생각', 8, 29, 2, 2),
#  ('걱정', 8, 48, 2, 1),
#  ('정확', 8, 0, 0, 0),
#  ('급하다', 8, 0, 0, 0),
#  ('같다(추측)', 8, 2, 0, 0),
#  ('해(하다)보다', 7, 3, 0, 1),
#  ('길(도로)', 7, 4, 0, 0),
#  ('내용', 7, 61, 0, 0),
#  ('홈페이지', 7, 4, 0, 0),
#  ('말(대화)', 7, 21, 0, 1),
#  ('결정(행동)', 7, 9, 0, 0),
#  ('상황(과정)', 7, 4, 0, 0),
#  ('바쁘다', 7, 11, 1, 0),
#  ('때(시간)', 7, 6, 0, 0),
#  ('때문에', 7, 1, 0, 2),
#  ('때문', 7, 0, 0, 0),
#  ('운동', 7, 29, 0, 1),
#  ('중(가운데)', 7, 1, 0, 0),
#  ('날(시간)', 7, 14, 0, 0),
#  ('하다', 7, 4, 3, 0),
#  ('것', 6, 3, 0, 0),
#  ('그거', 6, 1, 0, 0),
#  ('비싸다', 6, 0, 0, 0),
#  ('열다', 6, 5, 0, 0),
#  ('없다', 6, 3, 0, 1),
#  ('책임', 6, 7, 0, 0),
#  ('가렵다', 6, 3, 1, 0),
#  ('오르다', 6, 7, 1, 0),
#  ('줄다', 6, 18, 2, 0),
#  ('필수', 5, 0, 0, 0),
#  ('개인', 5, 0, 0, 0),
#  ('모두', 5, 0, 0, 0),
#  ('이유', 5, 39, 0, 0),
#  ('질문', 5, 99, 0, 1),
#  ('팀', 5, 2, 0, 0),
#  ('진행', 5, 9, 0, 1),
#  ('불량', 5, 1, 0, 0),
#  ('바뀌다', 5, 4, 0, 0),
#  ('계속', 5, 2, 0, 0),
#  ('변하다', 5, 16, 0, 0),
#  ('치료', 5, 14, 0, 0),
#  ('누르다', 5, 6, 0, 0),
#  ('떨어지다', 5, 6, 0, 0),
#  ('네', 5, 11, 0, 0),
#  ('돈', 5, 51, 0, 0),
#  ('이름', 5, 2, 0, 0),
#  ('불법', 5, 1, 0, 0),
#  ('알다', 5, 1, 0, 0),
#  ('말하다', 5, 5, 0, 0),
#  ('줄이다', 5, 0, 1, 0),
#  ('싫다', 5, 0, 0, 0),
#  ('상태', 5, 1, 0, 0),
#  ('아니다', 5, 148, 0, 0),
#  ('2', 5, 0, 0, 0),
#  ('낮다', 5, 5, 0, 0),
#  ('부러지다', 5, 2, 0, 0),
#  ('만들다', 5, 3, 0, 0),
#  ('동의', 5, 9, 0, 0),
#  ('다치다', 5, 8, 0, 0),
#  ('번호', 5, 10, 0, 0),
#  ('확실', 5, 3, 1, 0),
#  ('마시다', 4, 9, 1, 0),
#  ('앉다', 4, 1, 0, 0),
#  ('매일', 4, 2, 0, 1),
#  ('취소', 4, 2, 0, 0),
#  ('저혈당', 4, 10, 0, 0),
#  ('정상(제대로)', 4, 0, 0, 0),
#  ('단체', 4, 0, 0, 0),
#  ('하천', 4, 0, 0, 0),
#  ('기간', 4, 4, 0, 0),
#  ('올라가다', 4, 1, 2, 0),
#  ('재발', 4, 1, 0, 0),
#  ('독하다', 4, 1, 0, 0),
#  ('말(대화)하다', 4, 7, 0, 0),
#  ('결제', 4, 4, 0, 0),
#  ('설치', 4, 12, 0, 0),
#  ('교환', 4, 0, 0, 0),
#  ('제한', 4, 48, 0, 0),
#  ('기다리다', 4, 5, 0, 0),
#  ('전문(프로)', 4, 0, 0, 0),
#  ('부서', 4, 1, 0, 0),
#  ('작다', 4, 0, 0, 0),
#  ('대로(어미)', 4, 0, 0, 0),
#  ('증상', 4, 29, 0, 0),
#  ('예약', 4, 35, 1, 3),
#  ('공무원', 4, 1, 0, 0),
#  ('다른', 4, 0, 0, 0),
#  ('저리다', 4, 11, 0, 0),
#  ('빠르다', 4, 0, 0, 0),
#  ('바로', 4, 2, 0, 0),
#  ('정하다', 4, 10, 0, 0),
#  ('남다', 4, 9, 0, 0),
#  ('할인', 4, 25, 0, 0),
#  ('방법', 4, 130, 0, 0),
#  ('바꾸다', 4, 9, 2, 0),
#  ('팔다', 4, 2, 0, 1),
#  ('아', 4, 0, 0, 0),
#  ('확정', 4, 2, 0, 0),
#  ('복잡', 4, 3, 0, 0),
#  ('싸다(가격)', 3, 0, 0, 0),
#  ('도시', 3, 0, 0, 0),
#  ('특별하다', 3, 4, 0, 0),
#  ('관리', 3, 7, 0, 2),
#  ('답답', 3, 3, 0, 0),
#  ('부터', 3, 0, 0, 0),
#  ('궁금', 3, 125, 0, 0),
#  ('도청(기관)', 3, 0, 0, 0),
#  ('당뇨', 3, 9, 0, 0),
#  ('전(시간)', 3, 1, 0, 0),
#  ('같다(동일)', 3, 2, 0, 0),
#  ('하루종일', 3, 0, 0, 0),
#  ('점수', 3, 2, 0, 0),
#  ('전화번호', 3, 1, 0, 0),
#  ('통증', 3, 34, 0, 0),
#  ('듣다', 3, 5, 2, 0),
#  ('있어', 3, 0, 0, 0),
#  ('나다', 3, 1, 0, 0),
#  ('살다', 3, 2, 2, 0),
#  ('계산', 3, 0, 0, 0),
#  ('맡기다', 3, 0, 0, 0),
#  ('적다(분량)', 3, 0, 0, 0),
#  ('센터', 3, 2, 0, 0),
#  ('방식', 3, 0, 0, 0),
#  ('붓다(부풀다)', 3, 8, 0, 0),
#  ('과(부서)', 3, 1, 0, 0),
#  ('1', 3, 68, 0, 0),
#  ('나타나다', 3, 16, 0, 0),
#  ('운영', 3, 16, 0, 3),
#  ('멈추다', 3, 6, 0, 0),
#  ('낫다(우위)', 3, 0, 0, 0),
#  ('만나다', 3, 3, 0, 0),
#  ('추천', 3, 6, 0, 0),
#  ('위험', 3, 10, 0, 0),
#  ('출국', 3, 1, 0, 0),
#  ('낫다(치료)', 3, 3, 2, 0),
#  ('기관(기구)', 3, 0, 0, 0),
#  ('충분', 3, 1, 0, 0),
#  ('똑같다', 3, 0, 0, 0),
#  ('질문[주다]', 3, 8, 0, 0),
#  ('들어(상태)가다', 3, 0, 0, 0),
#  ('넉넉', 3, 0, 0, 0),
#  ('자르다', 3, 0, 0, 0),
#  ('기준', 3, 10, 0, 0),
#  ('죽다', 3, 1, 0, 0),
#  ('반응', 3, 1, 0, 0),
#  ('단속', 3, 1, 0, 0),
#  ('디스크', 3, 0, 0, 0),
#  ('집', 3, 15, 0, 0),
#  ('선택', 3, 0, 0, 0),
#  ('무엇', 3, 6, 0, 0),
#  ('빠지다(없어지다)', 3, 19, 0, 0),
#  ('본인', 3, 0, 0, 0),
#  ('치매', 3, 0, 0, 0),
#  ('진료', 3, 9, 0, 0),
#  ('수선(고침)', 3, 0, 0, 0),
#  ('깊다', 3, 0, 1, 0),
#  ('이곳', 3, 0, 0, 0),
#  ('까지', 3, 2, 0, 0),
#  ('완전', 3, 2, 0, 2),
#  ('춥다', 3, 4, 0, 0),
#  ('들어가다', 3, 0, 0, 0),
#  ('일부러', 2, 0, 0, 1),
#  ('주사(행동)하다', 2, 1, 0, 0),
#  ('잘', 2, 8, 0, 5),
#  ('학교', 2, 0, 0, 0),
#  ('관절염', 2, 0, 0, 0),
#  ('빼다', 2, 5, 0, 0),
#  ('구입', 2, 0, 0, 0),
#  ('모으다', 2, 0, 0, 0),
#  ('척추', 2, 0, 0, 0),
#  ('올리다', 2, 1, 0, 0),
#  ('늘리다', 2, 4, 1, 0),
#  ('다이어트', 2, 0, 0, 0),
#  ('업무', 2, 1, 0, 0),
#  ('이(이것)곳', 2, 1, 0, 0),
#  ('시험', 2, 2, 0, 0),
#  ('계획', 2, 23, 0, 0),
#  ('카드', 2, 4, 0, 0),
#  ('느끼다', 2, 10, 0, 0),
#  ('무시', 2, 0, 0, 0),
#  ('걷다(걸음)', 2, 3, 1, 0),
#  ('현금', 2, 0, 0, 0),
#  ('종양', 2, 0, 0, 0),
#  ('인터넷', 2, 2, 0, 0),
#  ('의미', 2, 20, 0, 0),
#  ('고장(결함)', 2, 1, 0, 0),
#  ('아마', 2, 1, 0, 0),
#  ('못(부정)가다', 2, 0, 0, 0),
#  ('무섭다', 2, 5, 0, 0),
#  ('거절', 2, 1, 0, 0),
#  ('동물', 2, 0, 0, 0),
#  ('편하다', 2, 0, 0, 0),
#  ('입금', 2, 2, 0, 0),
#  ('그정도', 2, 0, 0, 0),
#  ('오래걸리다', 2, 0, 0, 0),
#  ('모습', 2, 9, 0, 0),
#  ('교육', 2, 2, 0, 0),
#  ('어울리다', 2, 0, 0, 0),
#  ('0', 2, 0, 0, 0),
#  ('공황장애', 2, 0, 0, 0),
#  ('위법', 2, 0, 0, 0),
#  ('드리다', 2, 2, 5, 0),
#  ('어부', 2, 0, 0, 0),
#  ('핑계', 2, 1, 0, 0),
#  ('안되다', 2, 1, 0, 0),
#  ('들어(상태)오다', 2, 0, 1, 0),
#  ('밀리다', 2, 1, 0, 0),
#  ('일반', 2, 0, 0, 0),
#  ('새벽', 2, 1, 0, 0),
#  ('병(질환)', 2, 3, 0, 0),
#  ('대부분', 2, 3, 0, 0),
#  ('쓰다(작성)', 2, 4, 0, 0),
#  ('땅', 2, 0, 0, 0),
#  ('가져가다', 2, 0, 0, 1),
#  ('보호자', 2, 0, 0, 0),
#  ('그런', 2, 2, 0, 0),
#  ('이용', 2, 6, 0, 0),
#  ('해당', 2, 1, 0, 0),
#  ('주문', 2, 0, 0, 0),
#  ('버스', 2, 7, 0, 0),
#  ('장소', 2, 4, 0, 0),
#  ('적립', 2, 8, 0, 0),
#  ('입원', 2, 0, 0, 0),
#  ('넓다', 2, 0, 0, 0),
#  ('그러나', 2, 0, 0, 0),
#  ('최고', 2, 0, 0, 0),
#  ('위반', 2, 0, 0, 0),
#  ('#카라반', 2, 0, 0, 0),
#  ('노트북', 2, 1, 0, 0),
#  ('늘어나다', 2, 5, 0, 0),
#  ('덕분', 2, 0, 0, 0),
#  ('동그랗다', 2, 0, 0, 0),
#  ('그런것', 2, 1, 0, 0),
#  ('찾다', 2, 7, 0, 0),
#  ('진단', 2, 0, 0, 0),
#  ('불가능', 2, 0, 0, 0),
#  ('쉬다', 2, 4, 0, 0),
#  ('후', 2, 5, 0, 0),
#  ('왜', 2, 0, 0, 0),
#  ('든지', 2, 0, 0, 0),
#  ('부족', 2, 16, 0, 0),
#  ('낫다[치료](치료)', 2, 2, 0, 0),
#  ('직접', 2, 1, 0, 0),
#  ('체험', 2, 2, 0, 0),
#  ('중요', 2, 2, 1, 0),
#  ('손해', 2, 5, 0, 0),
#  ('신청', 2, 11, 2, 0),
#  ('끊기다', 2, 0, 0, 0),
#  ('방', 2, 9, 0, 0),
#  ('보이다', 2, 6, 1, 0),
#  ('거짓', 2, 0, 0, 0),
#  ('배송', 2, 0, 0, 0),
#  ('환불', 2, 1, 0, 0),
#  ('당뇨병', 2, 0, 0, 0),
#  ('안(부정)되다', 2, 1, 0, 0),
#  ('각각', 2, 0, 0, 0),
#  ('담배', 2, 5, 0, 2),
#  ('혼자', 2, 0, 0, 0),
#  ('좀', 2, 0, 0, 0),
#  ('정확하다', 2, 0, 0, 0),
#  ('일하다', 2, 3, 0, 0),
#  ('사업', 2, 0, 0, 0),
#  ('이상(정도)', 2, 3, 0, 0),
#  ('되지', 2, 0, 0, 0),
#  ('허락', 2, 12, 0, 0),
#  ('뼈', 2, 0, 0, 0),
#  ('힘들다(소모)', 2, 0, 0, 0),
#  ('양(동물)', 2, 0, 0, 0),
#  ('무조건', 2, 0, 0, 0),
#  ('결정', 2, 4, 0, 0),
#  ('당기다', 2, 0, 0, 0),
#  ('장애', 2, 0, 0, 0),
#  ('커지다', 2, 1, 1, 0),
#  ('인정(긍정)', 2, 7, 1, 0),
#  ('간단', 2, 0, 0, 0),
#  ('건너다', 2, 0, 0, 0),
#  ('만지다', 2, 0, 2, 0),
#  ('접속', 2, 0, 0, 0),
#  ('부담', 2, 14, 0, 0),
#  ('회사', 2, 0, 0, 0),
#  ('그건', 2, 0, 0, 0),
#  ('물(음료)', 2, 0, 0, 0),
#  ('쉬다(휴식)', 2, 21, 0, 1),
#  ('변경', 2, 5, 0, 0),
#  ('타다(오름)', 2, 0, 0, 0),
#  ('차량', 2, 0, 0, 0),
#  ('축제', 2, 3, 0, 0),
#  ('지역', 2, 1, 0, 0),
#  ('즉시', 2, 0, 0, 0),
#  ('움직이다', 2, 13, 0, 0),
#  ('효과', 2, 45, 0, 0),
#  ('가족', 2, 0, 0, 0),
#  ('책', 2, 2, 0, 0),
#  ('죄송', 2, 1, 0, 0),
#  ('불가', 2, 0, 0, 0),
#  ('항상', 2, 0, 0, 0),
#  ('자주', 2, 0, 0, 0),
#  ('가져오다', 2, 4, 0, 0),
#  ('가입', 2, 13, 0, 0),
#  ('귀찮다', 2, 5, 0, 1),
#  ('맞지(옳다)않다', 2, 1, 0, 0),
#  ('중요하다', 2, 0, 0, 0),
#  ('쓰다(사용)', 2, 3, 1, 0),
#  ('바르다(옳다)', 2, 0, 2, 0),
#  ('세우다', 2, 1, 0, 0),
#  ('100%', 2, 0, 0, 0),
#  ('1년', 2, 0, 0, 0),
#  ('질문하다', 2, 13, 0, 0),
#  ('회복', 2, 2, 0, 0),
#  ('한명(사람)', 1, 0, 0, 0),
#  ('그런건', 1, 1, 0, 0),
#  ('존재', 1, 0, 0, 0),
#  ('맞추다', 1, 0, 0, 0),
#  ('고생', 1, 4, 0, 0),
#  ('일요일', 1, 0, 0, 0),
#  ('오직', 1, 0, 0, 0),
#  ('별거', 1, 0, 0, 0),
#  ('천천히', 1, 0, 0, 0),
#  ('많이비싸다(가격)', 1, 0, 0, 0),
#  ('뚱뚱', 1, 0, 0, 0),
#  ('시내(도시)', 1, 0, 0, 0),
#  ('노력하다', 1, 0, 0, 0),
#  ('시설물', 1, 0, 0, 0),
#  ('마다', 1, 0, 0, 0),
#  ('완치', 1, 0, 0, 0),
#  ('또', 1, 12, 0, 0),
#  ('정보', 1, 15, 0, 0),
#  ('완벽', 1, 0, 0, 0),
#  ('오세요', 1, 0, 0, 0),
#  ('순서', 1, 0, 0, 0),
#  ('무리(벗어남)하다', 1, 1, 0, 0),
#  ('#VIP', 1, 0, 0, 0),
#  ('혹시', 1, 3, 0, 0),
#  ('딱딱(단단)하다', 1, 0, 0, 0),
#  ('젊다', 1, 0, 0, 0),
#  ('공식', 1, 0, 0, 0),
#  ('주(시간)', 1, 0, 0, 0),
#  ('그곳', 1, 2, 0, 1),
#  ('근처', 1, 0, 0, 0),
#  ('의사(사람)', 1, 0, 0, 0),
#  ('연기(지연)', 1, 1, 0, 0),
#  ('교사(사람)', 1, 0, 0, 0),
#  ('선착순', 1, 0, 0, 0),
#  ('심각', 1, 0, 0, 0),
#  ('담당자', 1, 4, 0, 0),
#  ('좋아지다', 1, 0, 0, 0),
#  ('주사(행동)', 1, 8, 3, 0),
#  ('마이페이지', 1, 0, 0, 0),
#  ('함께', 1, 2, 0, 0),
#  ('M', 1, 0, 0, 0),
#  ('확실히', 1, 0, 0, 0),
#  ('괜찮아', 1, 0, 0, 0),
#  ('재활', 1, 1, 0, 0),
#  ('스타일', 1, 0, 0, 0),
#  ('과체중', 1, 0, 0, 0),
#  ('시간', 1, 25, 0, 0),
#  ('30분', 1, 0, 0, 0),
#  ('개복수술', 1, 1, 0, 0),
#  ('단어', 1, 0, 0, 0),
#  ('심장', 1, 0, 0, 0),
#  ('대치', 1, 0, 0, 0),
#  ('외출', 1, 0, 0, 0),
#  ('파랗다', 1, 0, 0, 0),
#  ('잠깐', 1, 0, 0, 0),
#  ('벌다', 1, 0, 0, 0),
#  ('옮기다', 1, 0, 0, 0),
#  ('먼지', 1, 2, 0, 0),
#  ('가깝다', 1, 1, 0, 0),
#  ('가시', 1, 0, 0, 0),
#  ('도망', 1, 0, 0, 0),
#  ('영상(미디어)', 1, 3, 0, 0),
#  ('참여하다', 1, 0, 0, 0),
#  ('속하다[포함]', 1, 0, 0, 0),
#  ('켜지다', 1, 2, 0, 0),
#  ('혈종', 1, 0, 0, 0),
#  ('지하철', 1, 0, 0, 0),
#  ('이사(행동)', 1, 0, 0, 0),
#  ('간병인', 1, 0, 0, 0),
#  ('성격', 1, 0, 0, 0),
#  ('맘에들다(상태)', 1, 0, 0, 0),
#  ('부과', 1, 0, 0, 0),
#  ('전(시간)에', 1, 2, 0, 0),
#  ('착용', 1, 3, 0, 0),
#  ('시작', 1, 0, 0, 0),
#  ('그', 1, 1, 0, 0),
#  ('연락하다', 1, 1, 0, 0),
#  ('묻다(오염)', 1, 0, 0, 0),
#  ('지급', 1, 4, 0, 0),
#  ('상품(제품)', 1, 0, 0, 0),
#  ('하락', 1, 0, 0, 0),
#  ('내거', 1, 0, 0, 0),
#  ('보건소', 1, 0, 0, 0),
#  ('활용', 1, 0, 0, 0),
#  ('통(그릇)', 1, 3, 0, 0),
#  ('신다', 1, 0, 0, 0),
#  ('블랙', 1, 0, 0, 0),
#  ('과장(직책)', 1, 0, 0, 0),
#  ('휴가철', 1, 0, 0, 0),
#  ('군청(기관)', 1, 0, 0, 0),
#  ('숙박', 1, 1, 0, 0),
#  ('보내다', 1, 4, 0, 0),
#  ('구르다', 1, 0, 0, 0),
#  ('토요일', 1, 0, 0, 0),
#  ('팔', 1, 0, 0, 0),
#  ('조건', 1, 8, 0, 0),
#  ('청구', 1, 2, 0, 0),
#  ('부작용', 1, 17, 0, 0),
#  ('영광', 1, 0, 0, 0),
#  ('통돌이', 1, 0, 0, 0),
#  ('도와주다', 1, 1, 0, 0),
#  ('#세트', 1, 0, 0, 0),
#  ('법인', 1, 0, 0, 0),
#  ('민원인', 1, 0, 0, 0),
#  ('초과', 1, 3, 0, 0),
#  ('고정', 1, 1, 0, 0),
#  ('에어컨', 1, 2, 0, 0),
#  ('가득차다(가득함)', 1, 0, 0, 0),
#  ('신경쓰다', 1, 0, 0, 0),
#  ('초음파', 1, 0, 0, 0),
#  ('전혀', 1, 8, 0, 0),
#  ('고기', 1, 1, 0, 0),
#  ('짧다', 1, 0, 0, 0),
#  ('시간지나다', 1, 0, 0, 0),
#  ('전기통하다', 1, 0, 0, 0),
#  ('가끔', 1, 0, 0, 0),
#  ('겁내다', 1, 0, 0, 0),
#  ('예민하다[가시]', 1, 0, 0, 0),
#  ('모순', 1, 0, 0, 0),
#  ('끝나다', 1, 0, 0, 0),
#  ('촬영', 1, 0, 0, 0),
#  ('있다든지', 1, 0, 0, 0),
#  ('핫팩', 1, 0, 0, 0),
#  ('포인트', 1, 4, 0, 0),
#  ('수급', 1, 0, 0, 0),
#  ('이것[ㅇ수형]', 1, 0, 0, 0),
#  ('잘하다', 1, 0, 0, 0),
#  ('애매', 1, 0, 0, 0),
#  ('조금', 1, 1, 0, 0),
#  ('잊어버리다', 1, 0, 0, 0),
#  ('규제', 1, 2, 0, 0),
#  ('평등', 1, 0, 0, 0),
#  ('낚시', 1, 0, 0, 0),
#  ('따뜻하다', 1, 0, 0, 0),
#  ('해고', 1, 0, 0, 0),
#  ('소득', 1, 1, 0, 0),
#  ('위하다', 1, 0, 0, 0),
#  ('비밀', 1, 0, 0, 0),
#  ('삼십만', 1, 0, 0, 0),
#  ('겹치다', 1, 1, 0, 0),
#  ('땀나다', 1, 1, 0, 0),
#  ('알레르기', 1, 0, 0, 0),
#  ('다', 1, 0, 0, 0),
#  ('규칙', 1, 2, 0, 0),
#  ('횡성', 1, 0, 0, 0),
#  ('키우다', 1, 1, 0, 0),
#  ('답', 1, 7, 0, 0),
#  ('점(단위)', 1, 0, 0, 0),
#  ('가지고 있다', 1, 0, 0, 0),
#  ('다행', 1, 2, 0, 0),
#  ('통보', 1, 0, 0, 0),
#  ('우리(나의 무리)', 1, 0, 0, 0),
#  ('쌓이다', 1, 1, 0, 0),
#  ('반품', 1, 0, 0, 0),
#  ('이해', 1, 0, 0, 0),
#  ('도로(길)', 1, 1, 0, 0),
#  ('시청(기관)', 1, 0, 0, 0),
#  ('구분', 1, 6, 0, 0),
#  ('2개', 1, 0, 0, 0),
#  ('적다(쓰다)', 1, 1, 0, 0),
#  ('행동', 1, 2, 0, 0),
#  ('전문', 1, 0, 0, 0),
#  ('모노레일', 1, 0, 0, 0),
#  ('구글스토어', 1, 0, 0, 0),
#  ('절(사찰)', 1, 0, 0, 0),
#  ('병원', 1, 1, 0, 0),
#  ('떼어내다', 1, 0, 0, 0),
#  ('수고', 1, 2, 0, 0),
#  ('#완산구', 1, 0, 0, 0),
#  ('음식', 1, 6, 0, 0),
#  ('숙이다', 1, 1, 0, 0),
#  ('적용', 1, 1, 0, 3),
#  ('지원(도움)받다', 1, 0, 0, 0),
#  ('여섯시', 1, 0, 0, 0),
#  ('100 200만원', 1, 0, 0, 0),
#  ('넘치다', 1, 0, 0, 0),
#  ('계정', 1, 0, 0, 0),
#  ('금기증', 1, 0, 0, 0),
#  ('모욕', 1, 0, 0, 0),
#  ('다정', 1, 0, 0, 0),
#  ('여러 번', 1, 0, 0, 0),
#  ('가입하다', 1, 0, 0, 0),
#  ('들리다', 1, 0, 0, 0),
#  ('공원', 1, 1, 0, 0),
#  ('사고(일어난일)', 1, 1, 0, 0),
#  ('착각', 1, 0, 0, 0),
#  ('말다(중단)', 1, 2, 0, 0),
#  ('코로나', 1, 0, 0, 0),
#  ('미루다', 1, 4, 0, 1),
#  ('집회', 1, 0, 0, 0),
#  ('마약', 1, 0, 0, 0),
#  ('문(시설)닫다', 1, 0, 0, 0),
#  ('출발', 1, 0, 0, 0),
#  ('하하하', 1, 0, 0, 0),
#  ('한달', 1, 0, 0, 0),
#  ('이것', 1, 1, 0, 1),
#  ('적합하다', 1, 0, 0, 0),
#  ('발송', 1, 1, 0, 0),
#  ('유전', 1, 1, 0, 0),
#  ('감기', 1, 3, 0, 0),
#  ('시끄럽다', 1, 0, 0, 0),
#  ('냉동', 1, 0, 0, 0),
#  ('거짓말', 1, 0, 0, 0),
#  ('버리다', 1, 2, 1, 0),
#  ('어머', 1, 0, 0, 0),
#  ('장구(악기)치다', 1, 0, 0, 0),
#  ('자전거', 1, 1, 0, 0),
#  ('나쁘지', 1, 0, 2, 0),
#  ('절망', 1, 0, 0, 0),
#  ('염증', 1, 2, 0, 0),
#  ('잘못(부정)', 1, 0, 0, 0),
#  ('이상(상태)하다', 1, 10, 0, 0),
#  ('시스템', 1, 0, 0, 0),
#  ('퇴사', 1, 0, 0, 0),
#  ('민원실', 1, 1, 0, 0),
#  ('소유', 1, 1, 0, 0),
#  ('로그인', 1, 4, 0, 0),
#  ('방문', 1, 7, 0, 0),
#  ('악성', 1, 0, 0, 0),
#  ('뜨겁다', 1, 1, 0, 0),
#  ('굳다', 1, 0, 0, 0),
#  ('농업인', 1, 0, 0, 0),
#  ('그렇지', 1, 0, 1, 0),
#  ('풀어주다', 1, 0, 0, 0),
#  ('정기', 1, 0, 0, 0),
#  ('휴가', 1, 0, 0, 0),
#  ('건조(마름)', 1, 3, 1, 0),
#  ('벌써', 1, 1, 0, 0),
#  ('고속도로', 1, 0, 0, 0),
#  ('성인', 1, 0, 0, 0),
#  ('정문', 1, 0, 0, 0),
#  ('끊어지다', 1, 0, 0, 0),
#  ('덩어리', 1, 1, 0, 0),
#  ('네모', 1, 5, 0, 0),
#  ('전염', 1, 1, 0, 0),
#  ('상담', 1, 2, 0, 0),
#  ('가르다', 1, 0, 0, 0),
#  ('새(신)거', 1, 0, 0, 0),
#  ('월요일', 1, 0, 0, 0),
#  ('민원', 1, 2, 0, 0),
#  ('진료의뢰서', 1, 0, 0, 0),
#  ('장염', 1, 0, 0, 0),
#  ('고르다(선택)', 1, 0, 0, 0),
#  ('소멸', 1, 0, 0, 0),
#  ('권한', 1, 3, 0, 0),
#  ('마찬가지', 1, 0, 0, 0),
#  ('관리팀', 1, 0, 0, 0),
#  ('몇번', 1, 0, 0, 0),
#  ('제주도', 1, 0, 0, 0),
#  ('특별히', 1, 7, 0, 0),
#  ('거래', 1, 0, 0, 0),
#  ('절대', 1, 3, 0, 0),
#  ('뽑다', 1, 1, 0, 1),
#  ('소진', 1, 2, 0, 0),
#  ('그게', 1, 0, 0, 0),
#  ('쎄다', 1, 0, 0, 0),
#  ('소지(소유)', 1, 0, 0, 0),
#  ('위험군[위험 포험]', 1, 0, 0, 0),
#  ('개방', 1, 0, 0, 0),
#  ('침대', 1, 8, 0, 0),
#  ('포도막염', 1, 0, 0, 0),
#  ('문서', 1, 0, 0, 0),
#  ('화재수신기', 1, 0, 0, 0),
#  ('매주', 1, 0, 0, 0),
#  ('모이다', 1, 1, 0, 0),
#  ('의무', 1, 2, 0, 0),
#  ('정말', 1, 0, 0, 0),
#  ('홍길동', 1, 0, 0, 0),
#  ('줄어들다', 1, 7, 0, 0),
#  ('안내', 1, 6, 0, 0),
#  ('다른거', 1, 1, 0, 0),
#  ('한약', 1, 0, 0, 0),
#  ('샤워', 1, 0, 0, 0),
#  ('AI', 1, 0, 0, 0),
#  ('주택', 1, 0, 0, 0),
#  ('눈물', 1, 0, 0, 0),
#  ('이것[미성년자 가리킨다]가족', 1, 0, 0, 0),
#  ('찌릿', 1, 0, 0, 0),
#  ('살(피부)', 1, 0, 0, 0),
#  ('거기', 1, 0, 0, 1),
#  ('버튼누르다', 1, 0, 0, 0),
#  ('구부리다', 1, 0, 0, 0),
#  ('고치다', 1, 5, 0, 0),
#  ('카메라', 1, 0, 0, 0),
#  ('처음', 1, 1, 0, 0),
#  ('8만원', 1, 0, 0, 0),
#  ('적당히', 1, 0, 0, 0),
#  ('거역', 1, 0, 0, 0),
#  ('피다', 1, 1, 0, 0),
#  ('바라다', 1, 0, 0, 0),
#  ('비싸', 1, 0, 0, 0),
#  ('체험하다', 1, 0, 0, 0),
#  ('kg', 1, 0, 0, 0),
#  ('계약', 1, 1, 0, 0),
#  ('익숙', 1, 1, 1, 0),
#  ('신고하다', 1, 0, 0, 0),
#  ('서울', 1, 0, 0, 0),
#  ('7만원', 1, 0, 0, 0),
#  ('증감', 1, 0, 0, 0),
#  ('크리미너', 1, 0, 0, 0),
#  ('감염', 1, 3, 0, 0),
#  ('자다', 1, 1, 0, 0),
#  ('대답', 1, 3, 0, 0),
#  ('몸', 1, 0, 0, 0),
#  ('못(부정)', 1, 0, 0, 0),
#  ('무리', 1, 1, 0, 0),
#  ('사기(속임)', 1, 0, 0, 0),
#  ('계속하다', 1, 0, 0, 0),
#  ('사진', 1, 1, 0, 0),
#  ('얼마', 1, 1, 0, 0),
#  ('앞 열다', 1, 0, 0, 0),
#  ('염(질환)증(병증)', 1, 0, 0, 0),
#  ('꾸준히', 1, 0, 0, 0),
#  ('단계', 1, 0, 0, 0),
#  ('졸리다', 1, 1, 0, 0),
#  ('묻다', 1, 0, 0, 0),
#  ('지시[그런건]', 1, 0, 0, 0),
#  ('맞나(옳다)', 1, 0, 0, 0),
#  ('계시다', 1, 2, 0, 0),
#  ('녹음(기록)', 1, 0, 0, 0),
#  ('아직', 1, 18, 0, 0),
#  ('2일', 1, 0, 0, 0),
#  ('급여', 1, 0, 0, 0),
#  ('염(질환)', 1, 1, 0, 0),
#  ('매진(소진)', 1, 0, 0, 0),
#  ('않다', 1, 3, 0, 0),
#  ('이전(이동)', 1, 0, 0, 0),
#  ('못(부정)하다', 1, 0, 0, 0),
#  ('100', 1, 0, 0, 0),
#  ('수슬', 1, 0, 0, 0),
#  ('안전', 1, 0, 0, 0),
#  ('나무', 1, 1, 0, 0),
#  ('축산부', 1, 0, 0, 0),
#  ('말(대화)바꾸다', 1, 0, 0, 0),
#  ('한의원', 1, 0, 0, 0),
#  ('간호사', 1, 0, 0, 0),
#  ('연습', 1, 0, 0, 0),
#  ('안녕하세요', 1, 0, 0, 0),
#  ('참여', 1, 3, 0, 0),
#  ('먹지(먹다)', 1, 1, 8, 0),
#  ('타월', 1, 0, 0, 0),
#  ('일주일', 1, 0, 0, 0),
#  ('입력', 1, 3, 0, 0),
#  ('감경', 1, 1, 0, 0),
#  ('만큼', 1, 0, 0, 0),
#  ('틀리다', 1, 0, 0, 0),
#  ('부정맥', 1, 0, 0, 0),
#  ('건의', 1, 1, 0, 0),
#  ('부착', 1, 1, 0, 0),
#  ('신발', 1, 0, 0, 0),
#  ('림프', 1, 0, 0, 0),
#  ('택배 보내다', 1, 0, 0, 0),
#  ('돌려주다', 1, 0, 0, 0),
#  ('테이프', 1, 0, 0, 0),
#  ('사항', 1, 5, 0, 0),
#  ('화면', 1, 0, 0, 0),
#  ('없애다', 1, 0, 0, 0),
#  ('건물', 1, 3, 0, 0),
#  ('접수', 1, 5, 0, 0),
#  ('거짓말(대화)', 1, 0, 0, 0),
#  ('귀하다', 1, 0, 0, 0),
#  ('잠기다(빠지다)', 1, 0, 0, 0),
#  ('횡단보도(도로)', 1, 0, 0, 0),
#  ('지키다', 1, 3, 0, 0),
#  ('말해(하다)주다', 1, 0, 0, 0),
#  ('건강', 1, 0, 0, 0),
#  ('바보', 1, 0, 0, 0),
#  ('오십견', 1, 0, 0, 0),
#  ('노동부', 1, 0, 0, 0),
#  ('잘 알다', 1, 0, 0, 0),
#  ('욕', 1, 0, 0, 0),
#  ('장소[여기]', 1, 0, 0, 0),
#  ('여권', 1, 0, 0, 0),
#  ('만족', 1, 3, 0, 0),
#  ('주차장', 1, 5, 0, 0),
#  ('누락', 1, 7, 0, 0),
#  ('거부', 1, 0, 0, 0),
#  ('느리다', 1, 1, 0, 0),
#  ('딱맞다(옳다)', 1, 0, 0, 0),
#  ('저하', 1, 0, 0, 0),
#  ('달라', 1, 0, 0, 0),
#  ('#모텔', 1, 0, 0, 0),
#  ('왼손바닥오른손2 3펼쳐바닥뒹구수형', 1, 0, 0, 0),
#  ('힘줄', 1, 0, 0, 0),
#  ('켜다', 1, 2, 0, 0),
#  ('사용목적', 1, 0, 0, 0),
#  ('심각문제', 1, 0, 0, 0),
#  ('리모컨', 1, 2, 0, 0),
#  ('꺾이다', 1, 0, 0, 0),
#  ('금식', 1, 0, 0, 0),
#  ('등산', 1, 0, 0, 0),
#  ('사업자등록증', 1, 0, 0, 0),
#  ('캐시백[돈 적립]', 1, 0, 0, 0),
#  ('퍼지다', 1, 0, 0, 0),
#  ('다(모두)', 1, 0, 0, 0),
#  ('우리(나의무리)', 1, 0, 0, 0),
#  ('빠르지', 1, 0, 0, 0),
#  ('이틀', 1, 0, 0, 0),
#  ('내(나) 살(피부)', 1, 0, 0, 0),
#  ('한 교수님', 1, 0, 0, 0),
#  ('프로그램', 1, 2, 0, 0),
#  ('묻다(질문)', 1, 5, 0, 0),
#  ('벌어지다', 1, 0, 0, 0),
#  ('막히다', 1, 0, 0, 0),
#  ('무리(벗어남)', 1, 18, 0, 0),
#  ('소음', 1, 0, 0, 0),
#  ('필요없다', 1, 0, 0, 0),
#  ('확진', 1, 0, 0, 0),
#  ('[나에게]신청', 1, 0, 0, 0),
#  ('인천', 1, 0, 0, 0),
#  ('120', 1, 0, 0, 0),
#  ('내과(전문)', 1, 0, 0, 0),
#  ('당연하다', 1, 0, 0, 0),
#  ('보충', 1, 0, 0, 0),
#  ('급(급함)하다', 1, 1, 0, 0),
#  ('위(신체)염(질환)', 1, 0, 0, 0),
#  ('일반적', 1, 0, 0, 0),
#  ('시키다', 1, 0, 0, 0),
#  ('주인', 1, 1, 0, 0),
#  ('조사(살핌)', 1, 1, 0, 0),
#  ('여러가지(단위)', 1, 1, 0, 0),
#  ('판단', 1, 0, 0, 0),
#  ('서다', 1, 0, 0, 0),
#  ('경기(지명)도(주소)', 1, 0, 0, 0),
#  ('장난', 1, 1, 0, 0),
#  ('11월', 1, 0, 0, 0),
#  ('촛농', 1, 0, 0, 0),
#  ('실명(못봄)', 1, 0, 0, 0),
#  ('사무관', 1, 0, 0, 0),
#  ('12시', 1, 0, 0, 0),
#  ('오로지', 1, 0, 0, 0),
#  ('내려가다', 1, 0, 2, 0),
#  ('달', 1, 0, 0, 0),
#  ('문의', 1, 12, 0, 0),
#  ('10%', 1, 0, 0, 0),
#  ('몇일(날)전(시간)', 1, 0, 0, 0),
#  ('이상(상태)', 1, 36, 0, 0),
#  ('시술', 1, 1, 0, 0),
#  ('준비', 1, 14, 0, 0),
#  ('주문하다', 1, 0, 0, 0),
#  ('기억', 1, 41, 0, 0),
#  ('동안(시간)', 1, 0, 0, 0),
#  ('가능하다', 1, 0, 0, 0),
#  ('통세탁기', 1, 0, 0, 0),
#  ('과거', 1, 3, 0, 0),
#  ('부합', 1, 0, 0, 0),
#  ('추궁하다', 1, 0, 0, 0),
#  ('정지', 1, 1, 0, 0),
#  ('2만원', 1, 0, 0, 0),
#  ('말하다[나에게]', 1, 1, 0, 0),
#  ('삭제', 1, 1, 0, 0),
#  ('부천', 1, 0, 0, 0),
#  ('금방', 1, 0, 0, 0),
#  ('원활', 1, 0, 0, 0),
#  ('등급', 1, 0, 0, 0),
#  ('안과(전문)', 1, 0, 0, 0),
#  ('주사(행동)맞다(때림)', 1, 4, 0, 0),
#  ('오랫동안', 1, 0, 0, 0),
#  ('20일', 1, 0, 0, 0),
#  ('끊다', 1, 2, 0, 0),
#  ('역할', 1, 0, 0, 0),
#  ('2년', 1, 0, 0, 0),
#  ('서천', 1, 0, 0, 0),
#  ('필요하다', 1, 3, 0, 0),
#  ('벗다', 1, 0, 0, 0),
#  ('학생', 1, 0, 0, 0),
#  ('점선[흰 점선]', 1, 0, 0, 0),
#  ('빨리', 1, 0, 0, 0),
#  ('협박', 1, 0, 0, 0),
#  ('체질', 1, 0, 0, 0),
#  ('입구', 1, 0, 0, 0),
#  ('주말', 1, 0, 0, 0),
#  ('3번', 1, 0, 0, 0),
#  ('백혈병', 1, 0, 0, 0),
#  ('이론', 1, 0, 0, 0),
#  ('주', 1, 0, 0, 0),
#  ('그문제', 1, 0, 0, 0),
#  ('확실하다', 1, 1, 1, 0),
#  ('인허가', 1, 0, 0, 0),
#  ('겉', 1, 0, 0, 0),
#  ('생각하다', 1, 0, 0, 0),
#  ('세다(헤아리다)', 1, 0, 0, 0),
#  ('추천[받다]', 1, 0, 0, 0),
#  ('잠기다(걸다)', 1, 1, 0, 0),
#  ('지원(도움)', 1, 3, 0, 0),
#  ('신고', 1, 11, 0, 0),
#  ('구경', 1, 0, 0, 0),
#  ('내원', 1, 0, 0, 0),
#  ('팀장', 1, 0, 0, 0),
#  ('방문[오다]', 1, 0, 0, 0),
#  ('꾸준하다', 1, 0, 0, 0),
#  ('(음료)원인', 1, 0, 0, 0),
#  ('급행', 1, 0, 0, 0),
#  ('가슴열다', 1, 0, 0, 0),
#  ('지소', 1, 0, 0, 0),
#  ('점수판', 1, 0, 0, 0),
#  ('쇼크', 1, 0, 0, 0),
#  ('체험비', 1, 1, 0, 0),
#  ('모양', 1, 7, 0, 0),
#  ('취미', 1, 1, 0, 0),
#  ('서있다', 1, 0, 0, 0),
#  ('가르치다', 1, 1, 0, 0),
#  ('깨지다', 1, 0, 0, 0),
#  ('발(신체)', 1, 0, 0, 0),
#  ('불만', 1, 0, 0, 0),
#  ('검사', 1, 1, 0, 0),
#  ('오른쪽', 1, 0, 0, 0),
#  ('겨울', 1, 0, 0, 0),
#  ('이하', 1, 0, 0, 0),
#  ('화내다[양손]', 1, 0, 0, 0),
#  ('굽히다', 1, 3, 0, 0),
#  ('그런지', 1, 0, 0, 0),
#  ('그대로', 1, 0, 0, 0),
#  ('조절', 1, 1, 0, 1),
#  ('안돼', 1, 0, 0, 0),
#  ('떨리다', 1, 1, 0, 0),
#  ('당신', 1, 0, 0, 0),
#  ('집중', 1, 1, 0, 0),
#  ('관계', 1, 5, 0, 0),
#  ('알려주다', 1, 4, 0, 0),
#  ('3명', 1, 0, 0, 0),
#  ('이(이것)거', 1, 0, 0, 0),
#  ('상황', 1, 0, 0, 0),
#  ('친절', 1, 10, 0, 0),
#  ('봉사', 1, 0, 0, 0),
#  ('지시[여기]', 1, 0, 0, 0),
#  ('깁스', 1, 0, 0, 0),
#  ('안녕', 1, 0, 0, 0),
#  ('쿠폰', 1, 1, 0, 0),
#  ('시원', 1, 6, 0, 0),
#  ('ID', 1, 0, 0, 0),
#  ('안(안쪽)', 1, 0, 0, 0),
#  ('미안', 1, 3, 0, 0),
#  ('전통', 1, 1, 0, 0),
#  ('루푸스', 1, 0, 0, 0),
#  ('여전히', 1, 0, 0, 0),
#  ('시시하다', 1, 0, 0, 0),
#  ('이벤트', 1, 0, 0, 0),
#  ('절개', 1, 0, 0, 0),
#  ('뷔페', 1, 0, 0, 0),
#  ('같이(동일)', 1, 0, 0, 0),
#  ('말하다[상대방]', 1, 0, 0, 0),
#  ('힘들고', 1, 0, 0, 0),
#  ('색깔', 1, 0, 0, 0),
#  ('복구', 1, 3, 0, 0),
#  ('[많이]줄다', 1, 0, 0, 0),
#  ('자동차', 1, 1, 0, 0),
#  ('인출', 1, 0, 0, 0),
#  ('부탁', 1, 0, 0, 0),
#  ('결과', 1, 2, 0, 0),
#  ('헹구다', 1, 0, 0, 0),
#  ('유지', 1, 0, 0, 0),
#  ('신규', 1, 0, 0, 0),
#  ('경사(지형)급(급함)하다', 1, 0, 0, 0),
#  ('길', 1, 0, 0, 0),
#  ('요즘', 1, 2, 0, 0),
#  ('최근', 1, 0, 0, 0),
#  ('과(전문)', 1, 1, 0, 0),
#  ('온천', 1, 0, 0, 0),
#  ('보관', 1, 0, 0, 0),
#  ('양쪽', 1, 0, 0, 0),
#  ('말(대화)주다', 1, 0, 0, 0),
#  ('시설', 1, 2, 0, 0),
#  ('들다(행동)', 1, 1, 0, 0),
#  ('맞아(옳다)', 1, 0, 0, 0),
#  ('3단계', 1, 0, 0, 0),
#  ('재판', 1, 0, 0, 0),
#  ('혈족', 1, 0, 0, 0),
#  ('발견', 1, 3, 0, 0),
#  ('연결', 1, 3, 0, 0),
#  ('올해', 1, 0, 0, 0),
#  ('죄', 1, 0, 0, 0),
#  ('시계', 1, 0, 0, 0),
#  ('시원하게삼키다', 1, 0, 0, 0),
#  ('무감각', 1, 0, 0, 0),
#  ('완료', 1, 0, 0, 0),
#  ('알러지', 1, 1, 0, 0),
#  ('대상자', 1, 0, 0, 0),
#  ('수거', 0, 3, 0, 0),
#  ('접수[주다]', 0, 1, 0, 0),
#  ('그렇다', 0, 0, 1, 0),
#  ('제사', 0, 1, 0, 0),
#  ('방귀', 0, 1, 0, 0),
#  ('주소', 0, 1, 0, 0),
#  ('반환', 0, 1, 0, 0),
#  ('서서히[천천히]', 0, 1, 0, 0),
#  ('차이', 0, 29, 0, 0),
#  ('돈내다', 0, 8, 0, 0),
#  ('개관(건물)', 0, 1, 0, 0),
#  ('끈적임', 0, 1, 0, 0),
#  ('표현', 0, 3, 0, 0),
#  ('고혈압', 0, 5, 0, 0),
#  ('펜', 0, 1, 0, 0),
#  ('인슐린주사(행동)맞다(때림)', 0, 2, 0, 0),
#  ('나빠지다', 0, 3, 0, 0),
#  ('의심', 0, 6, 0, 0),
#  ('수', 0, 3, 0, 0),
#  ('가래(침)', 0, 1, 0, 0),
#  ('입(신체)맛', 0, 6, 0, 0),
#  ('감각', 0, 1, 0, 0),
#  ('쇠못', 0, 1, 0, 0),
#  ('충전', 0, 2, 0, 0),
#  ('바퀴', 0, 1, 0, 0),
#  ('문의 사항', 0, 1, 0, 0),
#  ('직업', 0, 1, 0, 0),
#  ('연락처', 0, 1, 0, 0),
#  ('골다공증[뼈 구멍 이것 병 모습]', 0, 1, 0, 0),
#  ('평가', 0, 1, 0, 0),
#  ('지불하다', 0, 2, 0, 0),
#  ('늘다', 0, 6, 1, 1),
#  ('커피', 0, 1, 0, 0),
#  ('합병증', 0, 2, 0, 0),
#  ('언제', 0, 1, 0, 0),
#  ('흐리다', 0, 1, 0, 0),
#  ('새(신)로(조사)', 0, 1, 0, 0),
#  ('차다(가득함)', 0, 1, 0, 0),
#  ('비(날씨)', 0, 7, 0, 0),
#  ('그동안', 0, 1, 0, 0),
#  ('빠지다[이빠지다](없어지다)', 0, 2, 0, 0),
#  ('약먹다', 0, 1, 0, 0),
#  ('중학교', 0, 1, 0, 0),
#  ...]

# %%
from openpyxl import Workbook

wb = Workbook()
sheet = wb["Sheet"]

header = ("left_word", "with_ani", "with_eps", "with_anh", "with_anha")

for row in [header, *left_wd_count]:
    sheet.append(row)

wb.save("./output/left_word_count.xlsx")
